# %%
import pandas as pd
oo = pd.read_csv(r'C:\Users\jopr1001\Downloads\Ex_Files_Pandas_EssT (1)\Ex_Files_Pandas_EssT\ExerciseFiles\data\olympics.csv', skiprows = 4)

# %%
oo.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.Edition.value_counts(ascending = True)
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Athlete.sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by =['Edition',"City",'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
oo[oo.Medal == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oo[oo.Sport.str.contains('Badminton')]
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20027  Barcelona     1992  Badminton  Badminton               LI, Yongbo  CHN
# 20028  Barcelona     1992  Badminton  Badminton            SIDEK, Rashid  MAS
# 20029  Barcelona     1992  Badminton  Badminton             SIDEK, Razif  MAS
# 20030  Barcelona     1992  Badminton  Badminton             TIAN, Bingyi  CHN
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# ...          ...      ...        ...        ...                      ...  ...
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
# 27742    Beijing     2008  Badminton  Badminton           LEE, Chong Wei  MAS
# 27743    Beijing     2008  Badminton  Badminton  YULIANTI, Maria Kristin  INA
# 27744    Beijing     2008  Badminton  Badminton              ZHANG, Ning  CHN
# 27745    Beijing     2008  Badminton  Badminton            XIE, Xingfang  CHN
#
# ...

# %%
ans = oo[(oo.Sport == "Badminton") & (oo.Event == "singles") & (oo.Gender == 'Men') & (oo.Medal == "Gold")]

# %%
ans.sort_values(by = ["Athlete"])
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %%
oo[oo.NOC == 'IND']
# Out:
#             City  Edition          Sport       Discipline  \
# 241        Paris     1900      Athletics        Athletics
# 244        Paris     1900      Athletics        Athletics
# 5512   Amsterdam     1928         Hockey           Hockey
# 5513   Amsterdam     1928         Hockey           Hockey
# 5514   Amsterdam     1928         Hockey           Hockey
# ...          ...      ...            ...              ...
# 25113     Sydney     2000  Weightlifting    Weightlifting
# 26870     Athens     2004       Shooting         Shooting
# 27922    Beijing     2008         Boxing           Boxing
# 28856    Beijing     2008       Shooting         Shooting
# 29165    Beijing     2008      Wrestling  Wrestling Free.
#
#                         Athlete  NOC Gender                      Event  \
# 241           PRITCHARD, Norman  IND    Men                       200m
# 244           PRITCHARD, Norman  IND    Men               200m hurdles
# ...

# %%
most = oo[oo.Edition >= 1984]
most.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
winner = oo[(oo.Gender == 'Men') & (oo.Medal == 'Gold') & (oo.Event == '100m')]
winner.sort_values(by = 'Edition', ascending = False)
# Out:
#                         City  Edition      Sport Discipline  \
# 27552                Beijing     2008  Athletics  Athletics
# 25539                 Athens     2004  Athletics  Athletics
# 23521                 Sydney     2000  Athletics  Athletics
# 21598                Atlanta     1996  Athletics  Athletics
# 19859              Barcelona     1992  Athletics  Athletics
# 18284                  Seoul     1988  Athletics  Athletics
# 16794            Los Angeles     1984  Athletics  Athletics
# 15374                 Moscow     1980  Athletics  Athletics
# 14069               Montreal     1976  Athletics  Athletics
# 12902                 Munich     1972  Athletics  Athletics
# 11865                 Mexico     1968  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# ...

# %%
winner2 = winner[['City', 'Edition', 'Athlete', 'NOC']]
winner2.sort_values('Edition', ascending = False)
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fo = oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts().plot(kind = 'bar', color = 'yellow');

# %%
fo.Sport.value_counts().plot(kind = 'barh');

# %%
fo.Sport.value_counts().plot(kind = 'pie');

# %%
#indexing
#set_index()
oo.set_index('Athlete', inplace = True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace = True)
oo.head()
# Out:
#    index             Athlete    City  Edition     Sport Discipline  NOC  \
# 0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN
# 1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE
# 3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
winner.head()
# Out:
#            City  Edition      Sport Discipline           Athlete  NOC Gender  \
# 13       Athens     1896  Athletics  Athletics     BURKE, Thomas  USA    Men
# 231       Paris     1900  Athletics  Athletics   JARVIS, Francis  USA    Men
# 737    St Louis     1904  Athletics  Athletics      HAHN, Archie  USA    Men
# 1191     London     1908  Athletics  Athletics  WALKER, Reginald  RSA    Men
# 2022  Stockholm     1912  Athletics  Athletics      CRAIG, Ralph  USA    Men
#
#      Event Event_gender Medal
# 13    100m            M  Gold
# 231   100m            M  Gold
# 737   100m            M  Gold
# 1191  100m            M  Gold
# 2022  100m            M  Gold

# %%
winner.set_index('Athlete', inplace = True)
winner.head()
# Out:
#                        City  Edition      Sport Discipline  NOC Gender Event  \
# Athlete
# BURKE, Thomas        Athens     1896  Athletics  Athletics  USA    Men  100m
# JARVIS, Francis       Paris     1900  Athletics  Athletics  USA    Men  100m
# HAHN, Archie       St Louis     1904  Athletics  Athletics  USA    Men  100m
# WALKER, Reginald     London     1908  Athletics  Athletics  RSA    Men  100m
# CRAIG, Ralph      Stockholm     1912  Athletics  Athletics  USA    Men  100m
#
#                  Event_gender Medal
# Athlete
# BURKE, Thomas               M  Gold
# JARVIS, Francis             M  Gold
# HAHN, Archie                M  Gold
# WALKER, Reginald            M  Gold
# CRAIG, Ralph                M  Gold

# %%
winner.sort_index(inplace = True, ascending = False)
# Out:
# C:\Users\jopr1001\AppData\Local\Temp\1/ipykernel_18072/4002918517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winner.sort_index(inplace = True, ascending = False)

# %%
winner.head()
# Out:
#                          City  Edition      Sport Discipline  NOC Gender  \
# Athlete
# WILLIAMS, Percy     Amsterdam     1928  Athletics  Athletics  CAN    Men
# WELLS, Allan           Moscow     1980  Athletics  Athletics  GBR    Men
# WALKER, Reginald       London     1908  Athletics  Athletics  RSA    Men
# TOLAN, Eddie      Los Angeles     1932  Athletics  Athletics  USA    Men
# REMIGINO, Lindy      Helsinki     1952  Athletics  Athletics  USA    Men
#
#                  Event Event_gender Medal
# Athlete
# WILLIAMS, Percy   100m            M  Gold
# WELLS, Allan      100m            M  Gold
# WALKER, Reginald  100m            M  Gold
# TOLAN, Eddie      100m            M  Gold
# REMIGINO, Lindy   100m            M  Gold

# %%
oo.set_index('Athlete', inplace = True)

# %%
oo.loc['BOLT, Usain']
# Out:
#              index     City  Edition      Sport Discipline  NOC Gender  \
# Athlete
# BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
#
#                     Event Event_gender Medal
# Athlete
# BOLT, Usain          100m            M  Gold
# BOLT, Usain          200m            M  Gold
# BOLT, Usain  4x100m relay            M  Gold

# %%
oo.reset_index(inplace = True)

# %%
oo.head()
# Out:
#               Athlete  index    City  Edition     Sport Discipline  NOC  \
# 0       HAJOS, Alfred      0  Athens     1896  Aquatics   Swimming  HUN
# 1    HERSCHMANN, Otto      1  Athens     1896  Aquatics   Swimming  AUT
# 2   DRIVAS, Dimitrios      2  Athens     1896  Aquatics   Swimming  GRE
# 3  MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE
# 4  CHASAPIS, Spiridon      4  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
oo.iloc[[1500, 2000, 2200]]
# Out:
#                    Athlete  index       City  Edition       Sport  \
# 1500         LEFDAHL, Rolf   1500     London     1908  Gymnastics
# 2000      PLETINCX, Joseph   2000  Stockholm     1912    Aquatics
# 2200  DE MONTIGNY, Fernand   2200  Stockholm     1912     Fencing
#
#        Discipline  NOC Gender             Event Event_gender   Medal
# 1500  Artistic G.  NOR    Men  team competition            M  Silver
# 2000   Water polo  BEL    Men        water polo            M  Bronze
# 2200      Fencing  BEL    Men         épée team            M    Gold

# %%
oo.iloc[1:8]
# Out:
#                  Athlete  index    City  Edition     Sport Discipline  NOC  \
# 1       HERSCHMANN, Otto      1  Athens     1896  Aquatics   Swimming  AUT
# 2      DRIVAS, Dimitrios      2  Athens     1896  Aquatics   Swimming  GRE
# 3     MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE
# 4     CHASAPIS, Spiridon      4  Athens     1896  Aquatics   Swimming  GRE
# 5  CHOROPHAS, Efstathios      5  Athens     1896  Aquatics   Swimming  GRE
# 6          HAJOS, Alfred      6  Athens     1896  Aquatics   Swimming  HUN
# 7       ANDREOU, Joannis      7  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver
# 5    Men             1200m freestyle            M  Bronze
# ...

# %%
oo.Edition.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
lastop = oo[oo.Edition == 2008]

# %%
medal_2008 = lastop.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# SUD      1
# EGY      1
# MDA      1
# TOG      1
# MRI      1
# Name: NOC, Length: 86, dtype: int64

# %%
som = pd.read_csv(r'C:\Users\jopr1001\Downloads\Ex_Files_Pandas_EssT (1)\Ex_Files_Pandas_EssT\ExerciseFiles\data\abc.csv')

# %%
som.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
som.set_index('Int Olympic Committee code', inplace = True)

# %%
som.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
som['Medal_2008'] = medal_2008

# %%
som.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             Medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
som[som.Medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...
