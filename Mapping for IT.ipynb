# %%
from zipfile import ZipFile
import os
import pandas as pd
main_path = input('Path of zip files : ')
extract_path = input('Path of extraction : ')
os.chdir(main_path)
for file in os.listdir():
    abc = ZipFile(file)
    abc.extractall(path = extract_path)
    print(file, ' extracted')
CAC = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","DESIRED EFFECT":"Functional claim 1","TARGET BODY PART":"Need Occasion 1","DAY/NIGHT":"Flavour Fragrance 1","SKIN TYPE":"Packaging Usage","ORGANIC CLAIM":"Flavour Fragrance 2","FRAGRANCE / INGREDIENT":"Functional Claim 2","RINSE OFF":"Functional Claim 3","SPF CLAIM":"Need Occasion 2","TOTAL SIZE":"Pack size"}
HCA = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","FRAGRANCE / INGREDIENT":"Functional Claim 2","DESIRED EFFECT":"Functional claim 1","LEAVE IN OR RINSE OUT":"Functional Claim 3","GREASE LEVEL":"Packaging Usage","HAIR CONDITION":"Flavour Fragrance 1","ANTI DANDRUFF":"Need Occasion 1","METHOD OF APPLICATION":"Flavour Fragrance 2","TOTAL SIZE":"Pack size","SIZE PER UNIT":"Need Occasion 2"}
HCO = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","COLOUR GROUP":"Flavour Fragrance 2","COLOUR":"Need Occasion 2","COLOUR CODE":"Functional Claim 3","PERMANENCE LEVEL":"Packaging Usage","AMMONIA FREE":"Functional Claim 2","METHOD OF APPLICATION":"Flavour Fragrance 1","INTENDED USE":"Functional claim 1","TARGET BODY PART":"Need Occasion 1","TOTAL SIZE":"Pack size"}
MKE = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","COSMETIC TYPE":"Pack size","GALENIC":"Product Form 1","COLOUR GROUP":"Flavour Fragrance 1","DESIRED EFFECT":"Functional claim 1","IF WITH LONG LASTING CLAIM":"Functional Claim 2","TARGET BODY PART":"Need Occasion 1","IF WITH HYPOALLERGENIC CLAIM":"Need Occasion 2","LEVEL OF WATER RESISTANCE CLAIM":"Functional Claim 3","STANDARD PACK OR REFILL":"Packaging Usage","ORGANIC CLAIM":"Flavour Fragrance 2"}
MKF = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","COLOUR GROUP":"Flavour Fragrance 1","DESIRED EFFECT":"Functional claim 1","IF WITH LONG LASTING CLAIM":"Functional Claim 2","IF WITH HYPOALLERGENIC CLAIM":"Need Occasion 2","SPF CLAIM":"Functional Claim 3","ORGANIC CLAIM":"Flavour Fragrance 2","METHOD OF APPLICATION":"Packaging Usage","TOTAL SIZE":"Pack size"}
MKL = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","COSMETIC TYPE":"Pack size","GALENIC":"Product Form 1","COLOUR GROUP":"Flavour Fragrance 1","DESIRED EFFECT":"Functional claim 1","IF WITH LONG LASTING CLAIM":"Functional Claim 2","METHOD OF APPLICATION":"Packaging Usage","IF WITH HYPOALLERGENIC CLAIM":"Need Occasion 2","LEVEL OF WATER RESISTANCE CLAIM":"Functional Claim 3","ORGANIC CLAIM":"Flavour Fragrance 2"}
MKO = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","ITEM IDENTIFIER":"Need Occasion 2"}
SCR = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","TARGET BODY PART":"Need Occasion 1","SKIN TYPE":"Functional claim 1","CONSUMER LIFESTAGE CLAIM":"Need Occasion 2","IF WITH SUN FACTOR/UV PROTECTION":"Functional Claim 2","SPF CLAIM":"Functional Claim 3","IF WITH FRAGRANCE FREE CLAIM":"Flavour Fragrance 1","METHOD OF APPLICATION":"Packaging Usage","ORGANIC CLAIM":"Flavour Fragrance 2","TOTAL SIZE":"Pack size"}
STL = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","GALENIC":"Product Form 1","DESIRED EFFECT":"Functional claim 1","DESCRIPTIVE STRENGTH CLAIM":"Flavour Fragrance 2","GREASE LEVEL":"Packaging Usage","HAIR CONDITION":"Functional Claim 3","METHOD OF APPLICATION":"Flavour Fragrance 1","TARGET BODY PART":"Need Occasion 1","IF ADDED FRAGRANCE":"Functional Claim 2","TOTAL SIZE":"Pack size","WEIGHT/VOLUME PER MEASURED UNIT - ACTUAL":"Need Occasion 2"}
MKN = {"EAN13":"Input_Item","LOCAL BRAND":"Local Brand","LOCAL MANUFACTURER":"LOCAL MANUFACTURER","ITEM IDENTIFIER":"Need Occasion 2","COSMETIC TYPE":"Pack size","COSMETIC DECORATION TYPE":"Need Occasion 1","GALENIC":"Product Form 1","FRAGRANCE / INGREDIENT":"Functional Claim 3","COLOUR GROUP":"Flavour Fragrance 1","DESIRED EFFECT":"Functional claim 1","IF WITH LONG LASTING CLAIM":"Functional Claim 2","METHOD OF APPLICATION":"Packaging Usage","ORGANIC CLAIM":"Flavour Fragrance 2"}
os.chdir(extract_path)
for file in os.listdir():
    if 'CAC' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = CAC, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'DataIntegration' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = HCA, inplace = True)
        file_read.to_excel('Mapping_HCA '+file,index=False)
        print(file, 'Created')
    elif 'HCO' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = HCO, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'MKE' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = MKE, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'MKF' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = MKF, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'MKL' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = MKL, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'MKO' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = MKO, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'SCR' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = SCR, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    elif 'STL' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = STL, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created') 
    elif 'MKN' in file:
        file_read = pd.read_excel(file)
        file_read.rename(columns = MKN, inplace = True)
        file_read.to_excel('Mapping '+file,index=False)
        print(file, 'Created')
    else:
        pass
for file3 in os.listdir():
    if 'Mapping' not in file3:
        os.remove(file3)
print('Mapping File creation is completed')
# Created By : Prakash Joshi
