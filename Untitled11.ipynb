# %%
import pandas as pd

# %%
df = pd.read_csv('df2.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_3760/2375945665.py in <module>
# ----> 1 df = pd.read_csv('df2.csv', index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df['new_col'] = df.area * df.price

# %%
df.columns
df2 = df[['area', 'price']]
df2
df2.drop(7)
# Out:
#     area    price
# 0   1500   384298
# 1   2000   452192
# 2   2200   479349
# 3   2300   492928
# 4   2500   520086
# 5   3400   642295
# 6   3600   669452
# 8   5000   859555
# 9   6000   995342
# 10  4500   791661
# 11  5400   913870
# 12  6500  1063236

# %%
df2['name'] = 'Prakash'
df2
# Out:
# C:\Users\jopr1001\AppData\Local\Temp\1/ipykernel_3760/1729859019.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['name'] = 'Prakash'
#     area    price     name
# 0   1500   384298  Prakash
# 1   2000   452192  Prakash
# 2   2200   479349  Prakash
# 3   2300   492928  Prakash
# 4   2500   520086  Prakash
# 5   3400   642295  Prakash
# 6   3600   669452  Prakash
# 7   4000   723767  Prakash
# 8   5000   859555  Prakash
# 9   6000   995342  Prakash
# 10  4500   791661  Prakash
# 11  5400   913870  Prakash
# 12  6500  1063236  Prakash

# %%
df1 = df[['area', 'price', 'new_col']]

# %%
df1
# Out:
#     area    price     new_col
# 0   1500   384298   576447000
# 1   2000   452192   904384000
# 2   2200   479349  1054567800
# 3   2300   492928  1133734400
# 4   2500   520086  1300215000
# 5   3400   642295  2183803000
# 6   3600   669452  2410027200
# 7   4000   723767  2895068000
# 8   5000   859555  4297775000
# 9   6000   995342  5972052000
# 10  4500   791661  3562474500
# 11  5400   913870  4934898000
# 12  6500  1063236  6911034000

# %%
df2.set_index('area', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_3760/2022937660.py in <module>
# ----> 1 df2.set_index('area', inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['area'] are in the columns"

# %%
df2.loc[6500, ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_3760/2432842086.py in <module>
# ----> 1 df2[df2.loc(0)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3418     def __getitem__(self, key):
#    3419         key = lib.item_from_zerodim(key)
# -> 3420         key = com.apply_if_callable(key, self)
#    3421
#    3422         if is_hashable(key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     635
#     636         if axis is not None:
# --> 637             axis = self.obj._get_axis_number(axis)
# ...

# %%
df3
# Out:
#     area    price     name
# 0   1500   384298  Prakash
# 12  6500  1063236  Prakash
