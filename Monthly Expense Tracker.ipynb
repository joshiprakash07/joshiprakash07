# %%
## Monthly expense tracker

# add sources of income as input
# chart of income
# balance after expence
#created functions
#used pandas
#used matplotlib
#used if else

#below are the income source list
salary = int(input("Salary : "))
freelance = int(input("freelance work : "))
trading = int(input("Stock trading : "))

#below are the expense list
grocery = int(input("Grocery Exp : "))
fuel    = int(input("Fuel Exp : "))
home_rent = int(input("Home Rent : "))
restorents = int(input("Restorents & movies : "))
online_shop = int(input("Online Shopping : "))
monthly_emi = int(input("Monthly Emi : "))
misc = int(input("misc Exp : "))
print("----------------------------------------------")

#Percentage Function
def per(total_list):
    tot_per = []
    for i in total_list:
        i = i*100/sum(total_list)
        tot_per.append(round(i,2))
        x = list(tot_per)
    return tot_per

#income source
total_income = [salary, freelance, trading]
label2 = ["Salary", "Freelance", "Trading"]
import pandas as pd
df2 = pd.DataFrame(list(zip(label2, total_income)), columns=['income', 'Amount'])
print(df2)
print("Your total income is ", sum(total_income))
print("Your Max income from source is ", max(total_income))
y = per(total_income)
print(y)
import matplotlib.pyplot as plt
label2 = ["Salary", "Freelance", "Trading"]
fig,ax = plt.subplots()
ax.pie(total_income, labels = label2, autopct="%.0f%%")
ax.set_title("Total Income Chart")
plt.show()
print("----------------------------------------------")
    
#exp sources
total_list = [grocery, fuel, home_rent, restorents, online_shop, misc, monthly_emi]
label1 = ["grocery", "fuel", "home_rent", "restorents", "online_shop", "misc", "monthly EMI"]
import pandas as pd
df = pd.DataFrame(list(zip(label1, total_list)), columns=['Expense', 'Amount'])
print(df)
print("Your total Exp  is ", sum(total_list))
print("Your maximum exp is ", max(total_list))
print("your minimum exp is ", min(total_list))
x = per(total_list)
print(x)

import matplotlib.pyplot as plt
label = ["grocery", "fuel", "home_rent", "restorents", "online_shop", "misc", "monthly EMI"]
fig,ax = plt.subplots()
ax.pie(total_list, labels = label, autopct="%.0f%%")
ax.set_title("Total Expense Chart")
plt.show()
print("----------------------------------------------")

# Income vs expence = savings or debt
a = sum(total_income)
b = sum(total_list)
savings = a - b
if savings > 0:
    print("your savings are ", savings)
else:
    print("your debts are ", savings)
savings_list = [a, b]

import matplotlib.pyplot as plt
rupees = [a, b]
income_vs_exp = ["Income", "Expense"]
plt.bar(income_vs_exp, rupees)
plt.title('Income and Expense')
plt.xlabel('Income vs exp')
plt.ylabel('Rupees')
plt.show()
# Out:
# Salary : 24000
# freelance work : 0
# Stock trading : 0
# Grocery Exp : 2500
# Fuel Exp : 1500
# Home Rent : 4000
# Restorents & movies : 2500
# Online Shopping : 2000
# Monthly Emi : 4800
# misc Exp : 4000
# ----------------------------------------------
#       income  Amount
# 0     Salary   24000
# 1  Freelance       0
# 2    Trading       0
# Your total income is  24000
# Your Max income from source is  24000
# [100.0, 0.0, 0.0]
# ----------------------------------------------
#        Expense  Amount
# 0      grocery    2500
# 1         fuel    1500
# 2    home_rent    4000
# 3   restorents    2500
# 4  online_shop    2000
# 5         misc    4000
# 6  monthly EMI    4800
# Your total Exp  is  21300
# Your maximum exp is  4800
# your minimum exp is  1500
# [11.74, 7.04, 18.78, 11.74, 9.39, 18.78, 22.54]
# ----------------------------------------------
# your savings are  2700
